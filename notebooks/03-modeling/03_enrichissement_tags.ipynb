# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfVectorizer
ROOT = Path.cwd().parents[1]
DATA = ROOT / "data" / "raw" / "movielens"

# %%
df = pd.read_csv(ROOT / "notebooks" / "02-preprocessing" / "movies_preprocessed_clean.csv", index_col=0)
tags = pd.read_csv(DATA / "tags.csv")
links = pd.read_csv(DATA / "links.csv")
cast = pd.read_csv(ROOT / "notebooks" / "02-preprocessing" /  "cast_group_clean.csv", index_col=0)

# %% [markdown]
# Avant tout on regarde si il manque de la donnée

# %%
tags.isna().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags = tags.dropna(subset=['tag'])

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
tags['movieId'].value_counts()
# Out:
# movieId
# 296      1994
# 2959     1779
# 79132    1552
# 2571     1430
# 318      1339
#          ...
# 8642        1
# 67894       1
# 73501       1
# 84553       1
# 1495        1
# Name: count, Length: 19545, dtype: int64

# %%
tags['tag'].value_counts().head(30)
# Out:
# tag
# sci-fi                3384
# based on a book       3281
# atmospheric           2917
# comedy                2779
# action                2657
# surreal               2427
# BD-R                  2334
# twist ending          2323
# funny                 2072
# dystopia              1991
# stylized              1941
# quirky                1906
# dark comedy           1899
# classic               1769
# psychology            1754
# fantasy               1703
# time travel           1549
# romance               1534
# visually appealing    1509
# disturbing            1487
# aliens                1428
# thought-provoking     1422
# social commentary     1417
# Nudity (Topless)      1400
# violence              1336
# drugs                 1312
# Criterion             1286
# true story            1276
# nudity (topless)      1245
# adventure             1243
# Name: count, dtype: int64

# %% [markdown]
# On voit clairement qu'il y as enormement de doublons de tag, qui sont liés uniquement a une majuscule presente dans un groupe et pas dans l'autre,
# je vais donc tout standardiser, tout en minuscule + strip

# %%
tags['tag'] = tags["tag"].str.lower().str.strip()

# %%
tags['tag'].value_counts().head(30)
# Out:
# tag
# sci-fi                3576
# based on a book       3307
# atmospheric           3169
# comedy                3078
# action                3068
# nudity (topless)      2646
# surreal               2528
# twist ending          2367
# bd-r                  2334
# funny                 2253
# quirky                2034
# dystopia              2015
# classic               1971
# stylized              1944
# dark comedy           1910
# romance               1874
# fantasy               1850
# psychology            1763
# time travel           1572
# disturbing            1524
# visually appealing    1511
# aliens                1439
# social commentary     1424
# thought-provoking     1422
# adventure             1374
# violence              1361
# criterion             1352
# animation             1345
# drugs                 1336
# dark                  1312
# Name: count, dtype: int64

# %% [markdown]
# Le set est beaucoup mieux organisé, je vais regrouper tout ca pour une ligne de mot par films

# %%
tags_agg = tags.groupby('movieId')['tag'].agg(' '.join).reset_index()

# %%
tags_agg.head()
# Out:
#    movieId                                                tag
# 0        1  watched computer animation disney animated fea...
# 1        2  time travel adapted from:book board game child...
# 2        3  old people that is actually funny sequel fever...
# 3        4  chick flick revenge characters chick flick cha...
# 4        5  diane keaton family sequel steve martin weddin...

# %% [markdown]
# Le fichier links va faire le lien entre les 2 DF

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
tags_links = tags_agg.merge(links, on="movieId", how="inner")

tags_links.head()
tags_links.shape
# Out:
# (19545, 4)

# %%
tags_links["imdbId"] = "tt" + tags_links['imdbId'].astype(str).str.zfill(7)

# %%
tags_links['imdbId'].head()
# Out:
# 0    tt0114709
# 1    tt0113497
# 2    tt0113228
# 3    tt0114885
# 4    tt0113041
# Name: imdbId, dtype: str

# %%
df = df.reset_index()

# %% [markdown]
# Je decide de garder tout les films memes sans tag movielens, le but etant d'enrichire les films avec certain tag utilisateur

# %%
final = df.merge(tags_links, left_on='tconst', right_on='imdbId', how='left')

# %%
final.head()
# Out:
#       tconst                   primaryTitle  startYear  runtimeMinutes  \
# 0  tt0000009                     Miss Jerry     1894.0            45.0
# 1  tt0000147  The Corbett-Fitzsimmons Fight     1897.0           100.0
# 2  tt0000574    The Story of the Kelly Gang     1906.0            70.0
# 3  tt0000591               The Prodigal Son     1907.0            90.0
# 4  tt0000615             Robbery Under Arms     1907.0             NaN
#
#    averageRating  numVotes  weight_rating  Action  Adult  Adventure  ...  \
# 0            5.3     236.0       6.125416       0      0          0  ...
# 1            5.3     600.0       6.081154       0      0          0  ...
# 2            6.0    1067.0       6.133821       1      0          1  ...
# 3            5.0      39.0       6.149650       0      0          0  ...
# 4            3.4      34.0       6.141831       0      0          0  ...
#
#    Sci-Fi  Sport  Talk-Show  Thriller  War  Western  movieId  tag  imdbId  \
# 0       0      0          0         0    0        0      NaN  NaN     NaN
# 1       0      1          0         0    0        0      NaN  NaN     NaN
# 2       0      0          0         0    0        0      NaN  NaN     NaN
# 3       0      0          0         0    0        0      NaN  NaN     NaN
# 4       0      0          0         0    0        0      NaN  NaN     NaN
#
#    tmdbId
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 38 columns]

# %%
final.shape
# Out:
# (330702, 38)

# %%
 
df.shape
# Out:
# (330702, 34)

# %%
final.columns
# Out:
# Index(['tconst', 'primaryTitle', 'startYear', 'runtimeMinutes',
#        'averageRating', 'numVotes', 'weight_rating', 'Action', 'Adult',
#        'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History',
#        'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV',
#        'Romance', 'Sci-Fi', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western',
#        'movieId', 'tag', 'imdbId', 'tmdbId'],
#       dtype='str')

# %%
final['tag'].isna().sum()
# Out:
# np.int64(312824)

# %%
final['tag'] = final['tag'].fillna('')

# %% [markdown]
# Je merge mon cast avec mon df final

# %%
cast_final = final.merge(cast, how='left', on="tconst")

# %%
cast_final = cast_final.drop(["movieId", "imdbId", "tmdbId"], axis=1)

# %%
cast_final['tag'] = cast_final['tag'].fillna('')
cast_final['clean_name'] = cast_final['clean_name'].fillna('')

# %%
cast_final.shape
# Out:
# (330702, 36)

# %%
(cast_final['tag'] != '').sum()
# Out:
# np.int64(17878)

# %%
cast_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 330702 entries, 0 to 330701
# Data columns (total 36 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          330702 non-null  str
#  1   primaryTitle    330700 non-null  str
#  2   startYear       330665 non-null  float64
#  3   runtimeMinutes  301550 non-null  float64
#  4   averageRating   330702 non-null  float64
#  5   numVotes        330702 non-null  float64
#  6   weight_rating   330702 non-null  float64
#  7   Action          330702 non-null  int64
#  8   Adult           330702 non-null  int64
#  9   Adventure       330702 non-null  int64
#  10  Animation       330702 non-null  int64
#  11  Biography       330702 non-null  int64
#  12  Comedy          330702 non-null  int64
#  13  Crime           330702 non-null  int64
#  14  Documentary     330702 non-null  int64
#  15  Drama           330702 non-null  int64
#  16  Family          330702 non-null  int64
#  17  Fantasy         330702 non-null  int64
#  18  Film-Noir       330702 non-null  int64
#  19  Game-Show       330702 non-null  int64
#  20  History         330702 non-null  int64
#  21  Horror          330702 non-null  int64
#  22  Music           330702 non-null  int64
#  23  Musical         330702 non-null  int64
#  24  Mystery         330702 non-null  int64
#  25  News            330702 non-null  int64
#  26  Reality-TV      330702 non-null  int64
#  27  Romance         330702 non-null  int64
#  28  Sci-Fi          330702 non-null  int64
#  29  Sport           330702 non-null  int64
#  30  Talk-Show       330702 non-null  int64
#  31  Thriller        330702 non-null  int64
#  32  War             330702 non-null  int64
#  33  Western         330702 non-null  int64
#  34  tag             330702 non-null  str
#  35  clean_name      330702 non-null  str
# dtypes: float64(5), int64(27), str(4)
# memory usage: 141.9 MB

# %% [markdown]
# # 17878 films enrichis en casting + tags utilisateurs

# %% [markdown]
#  Je crée 3 matrice, Genre, Cast et Tags que je normalise pour egalisé le poid

# %%
genre_cols = cast_final.loc[:, 'Action':'Western'].columns.tolist()

CV = CountVectorizer()

cast_sparse = CV.fit_transform(cast_final['clean_name'])
genre_sparse = csr_matrix(cast_final[genre_cols].values)

genre_matrice = normalize(genre_sparse)

cast_matrice = normalize(cast_sparse)

TFIDF = TfidfVectorizer()

tags_sparse = TFIDF.fit_transform(cast_final['tag'])

tags_matrice = normalize(tags_sparse)

# %%
genre_w = genre_matrice * 1.0
cast_w = cast_matrice * 1
tags_w = tags_matrice * 1

# %%
matrice = hstack([genre_w, cast_w, tags_w]).tocsr()

position = 0
scores = cosine_similarity(matrice[position], matrice)

scores = scores.flatten()
ordre = scores.argsort()[::-1]
top = ordre[1:11]

# %%
def recherche_par_titre(titre, n=10):
    matches = cast_final[cast_final['primaryTitle'].str.contains(titre, case=False, na=False)]
    if matches.empty:
        return f"Aucun film trouvé pour '{titre}'"
    position = matches.sort_values('weight_rating', ascending=False).index[0]

    sims = cosine_similarity(matrice[position], matrice).flatten()
    df_temp = cast_final.copy()
    df_temp['sim'] = sims

    df_temp = df_temp.drop(position)
    print(cast_final.loc[position, 'primaryTitle'])
    df_temp = df_temp.sort_values(['sim', 'weight_rating'], ascending=[False, False])
    return df_temp[['primaryTitle', 'startYear', 'clean_name', 'weight_rating', 'sim']].head(n)

# %%
cast_final.index.equals(pd.RangeIndex(len(cast_final)))

## index de cast_final doit rester 0..n sans trou (matrice[position] = position, pas étiquette)
# Out:
# True

# %%
recherche_par_titre('Matrix')
# Out:
# The Matrix
#                        primaryTitle  startYear  \
# 95671        The Matrix Revolutions     2003.0
# 94024           The Matrix Reloaded     2003.0
# 185959           RiffTrax: Firehead     2013.0
# 33390                    Armageddon     1969.0
# 151179     The Matrix Resurrections     2021.0
# 46454                          Tron     1982.0
# 37890                      Superman     1973.0
# 193908  Rifftrax: Avengers: Endgame     2020.0
# 233226          Rifftrax: Dune 2021     2022.0
# 195661         Rifftrax: The Matrix     2006.0
#
#                                                clean_name  weight_rating  \
# 95671   keanureeves laurencefishburne carrie-annemoss ...       6.694208
# 94024   keanureeves laurencefishburne carrie-annemoss ...       7.190439
# 185959                                                          6.168302
# 33390                                                           6.160124
# 151179  keanureeves keanureeves carrie-annemoss carrie...       5.611176
# 46454   jeffbridges jeffbridges bruceboxleitner bruceb...       6.677891
# 37890                                                           6.165462
# 193908                                                          6.164134
# 233226                                                          6.163263
# 195661                                                          6.162611
#
#              sim
# 95671   0.789898
# 94024   0.775605
# 185959  0.577350
# 33390   0.577350
# 151179  0.558034
# 46454   0.471616
# 37890   0.471405
# 193908  0.471405
# 233226  0.471405
# 195661  0.471405

# %% [markdown]
# Les films sans cast sont avantager , on peut voir que la similarité est identique et le WR vratiment proche sur le 2 films sans cast
# RiffTrax: Firehead	2013.0		6.168302	0.808452 \n
#     	Armageddon	1969.0		6.160124	0.808452

# %%
df['numVotes'].describe()
# Out:
# count    3.307020e+05
# mean     3.825301e+03
# std      3.838376e+04
# min      5.000000e+00
# 25%      2.200000e+01
# 50%      7.000000e+01
# 75%      3.480000e+02
# max      3.175959e+06
# Name: numVotes, dtype: float64

# %%
df['numVotes'].quantile([0.8, 0.9, 0.92, 0.95, 0.99])
# Out:
# 0.80      546.00
# 0.90     1943.00
# 0.92     2825.00
# 0.95     6187.95
# 0.99    77239.73
# Name: numVotes, dtype: float64

# %% [markdown]
# On va filtrer par nombres de votes, sur le quantile 92 qui est a 2825 notes

# %%
cast_final_Q92 = cast_final[cast_final['numVotes'] >= df['numVotes'].quantile(0.92)].reset_index(drop=True)

# %%
cast_final_Q92.shape
# Out:
# (26463, 36)

# %%
genre_cols = cast_final_Q92.loc[:, 'Action':'Western'].columns.tolist()

CV = CountVectorizer()

cast_sparse = CV.fit_transform(cast_final_Q92['clean_name'])
genre_sparse = csr_matrix(cast_final_Q92[genre_cols].values)

genre_matrice = normalize(genre_sparse)

cast_matrice = normalize(cast_sparse)

TFIDF = TfidfVectorizer()

tags_sparse = TFIDF.fit_transform(cast_final_Q92['tag'])

tags_matrice = normalize(tags_sparse)

genre_w = genre_matrice * 1.0
cast_w = cast_matrice * 0.4
tags_w = tags_matrice * 0.2

matrice = hstack([genre_w, cast_w, tags_w]).tocsr()

def recherche_par_titre(titre, n=10):
    matches = cast_final_Q92[cast_final_Q92['primaryTitle'].str.contains(titre, case=False, na=False)]
    if matches.empty:
        return f"Aucun film trouvé pour '{titre}'"
    position = matches.sort_values('weight_rating', ascending=False).index[0]

    print(cast_final_Q92.loc[position, ['primaryTitle']])

    sims = cosine_similarity(matrice[position], matrice).flatten()
    df_temp = cast_final_Q92.copy()
    df_temp['sim'] = sims

    df_temp = df_temp.drop(position)
    
    df_temp = df_temp.sort_values(['sim'], ascending=[False])
    return df_temp[['primaryTitle', 'startYear', 'clean_name', 'weight_rating','tag', 'sim' ]].head(n)

# %%
recherche_par_titre('Hachi')
# Out:
# primaryTitle    Hachi: A Dog's Tale
# Name: 13353, dtype: str
#                               primaryTitle  startYear  \
# 24486                        Penguin Bloom     2020.0
# 17330            Goodbye Christopher Robin     2017.0
# 24575                   I Can Only Imagine     2018.0
# 17063                            Aparajito     2022.0
# 23749            Jacob's Kingdom of Heaven     2016.0
# 21478  A Beautiful Day in the Neighborhood     2019.0
# 19635                          Unsung Hero     2024.0
# 14139                      Rescued by Ruby     2022.0
# 13979                           White Bird     2023.0
# 22123               A Street Cat Named Bob     2016.0
#
#                                               clean_name  weight_rating tag  \
# 24486  naomiwatts griffinmurray-johnston andrewlincol...       6.598465
# 17330  domhnallgleeson margotrobbie kellymacdonald vi...       6.945705
# 24575  johnmichaelfinley madelinecarroll dennisquaid ...       7.035304
# 17063  jeetukamal saayonighosh debashisroy paranbaner...       7.363553
# 23749  nivinpauly renjipanicker lakshmyramakrishnan s...       6.683965
# 21478  matthewrhys tomhanks chriscooper susankelechiw...       7.135575
# 19635  daisybetts joeldavidsmallbone kirrileeberger j...       6.566506
# 14139  grantgustin scottwolf kaylahzander camillesull...       6.874203
# 13979  ariellaglaser orlandoschwerdt gilliananderson ...       6.879759
# 22123  luketreadaway bobthecat rutagedmintas joannefr...       7.135581
#
#             sim
# 24486  0.847579
# 17330  0.847579
# 24575  0.847579
# 17063  0.847579
# 23749  0.847579
# 21478  0.847579
# 19635  0.847579
# 14139  0.847579
# 13979  0.847579
# 22123  0.847579

# %%
def recherche_par_titre(titre, n=10):
    exact = cast_final_Q92[cast_final_Q92['primaryTitle'].str.lower() == titre.lower()]
    if not exact.empty:
        matches = exact
        position = matches.sort_values('numVotes', ascending=False).index[0]
    else:
        matches = cast_final_Q92[cast_final_Q92['primaryTitle'].str.contains(titre, case=False, na=False)]
        if matches.empty:
            return f"Aucun film trouvé pour '{titre}'"
        position = matches.sort_values('weight_rating', ascending=False).index[0]

    print(cast_final_Q92.loc[position, ['primaryTitle', 'startYear']])

    sims = cosine_similarity(matrice[position], matrice).flatten()
    df_temp = cast_final_Q92.copy()
    df_temp['sim'] = sims

    df_temp = df_temp.drop(position)
    df_temp = df_temp.sort_values(['sim'], ascending=[False])
    return df_temp[['primaryTitle', 'startYear', 'clean_name', 'weight_rating', 'tag', 'sim']].head(n)

# %%
recherche_par_titre('evil dead')
# Out:
# primaryTitle    Evil Dead
# startYear          2013.0
# Name: 15204, dtype: object
#                 primaryTitle  startYear  \
# 24409      The Russian Bride     2018.0
# 18556              Play Dead     2022.0
# 26224               Candyman     2021.0
# 21120  Grace: The Possession     2014.0
# 22062           Vash Level 2     2025.0
# 18235                  Nurse     2013.0
# 20989   Deep in the Darkness     2014.0
# 22627         He's Out There     2018.0
# 21030         Jacob's Ladder     2019.0
# 21724             Sugar Mill     2025.0
#
#                                               clean_name  weight_rating tag  \
# 24409  corbinbernsen oksanaorlan kristinapimenova lis...       5.758503
# 18556  baileemadison jerryo'connell anthonyturpel chr...       5.712175
# 26224  yahyaabdul-mateenii teyonahparris nathanstewar...       5.917793
# 21120  alexiafast alexiafast linshaye alandale alexis...       5.538716
# 22062  jankibodiwala hitukanodia hitenkumar hitenkuma...       6.598219
# 18235  pazdelahuerta katrinabowden juddnelson corbinb...       5.058341
# 20989  seanpatrickthomas deanstockwell blanchebaker k...       5.660201
# 22627  yvonnestrahovski annapniowsky abigailpniowsky ...       5.619482
# 21030  michaelealy jessewilliams nicolebeharie guybur...       5.174644
# 21724  arbaniyasiz ersyaaurelia erikacarlina bukiebma...       6.073677
#
#             sim
# 24409  0.847579
# 18556  0.847579
# 26224  0.847579
# 21120  0.847579
# 22062  0.847579
# 18235  0.847579
# 20989  0.847579
# 22627  0.847579
# 21030  0.847579
# 21724  0.847579

# %% [markdown]
# Je vais faire une fonction de recherche par genre aussi

# %%
def recherche_par_genre(genre, n=20):
    mapping = {g.lower(): g for g in genre_cols}
    genre_col = mapping.get(genre.lower())
    if genre_col is None:
          return f"Genre '{genre}' inconnu"

    matches = cast_final_Q92[genre_col] == 1
    films = cast_final_Q92[matches]
    if films.empty:
         return f"Aucun film trouvé pour '{genre}'"

    
    films_tries = films.sort_values('weight_rating', ascending=False)
    return films_tries[['primaryTitle', 'startYear', 'weight_rating']].head(n)

# %%
print(genre_cols)
# Out:
# ['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']

# %%
recherche_par_genre('Horror')
# Out:
#                            primaryTitle  startYear  weight_rating
# 6149           The Silence of the Lambs     1991.0       8.591223
# 3757                              Alien     1979.0       8.486408
# 1747                             Psycho     1960.0       8.481634
# 4017                        The Shining     1980.0       8.388693
# 4891                             Aliens     1986.0       8.383569
# 4335                          The Thing     1982.0       8.176171
# 3365                               Jaws     1975.0       8.083771
# 3098                       The Exorcist     1973.0       8.076121
# 25647                           Tumbbad     2018.0       8.043367
# 2537                    Rosemary's Baby     1968.0       7.956697
# 1226                         Diabolique     1955.0       7.948662
# 8885                  Manichithrathazhu     1993.0       7.931572
# 8           The Cabinet of Dr. Caligari     1920.0       7.861305
# 1943   What Ever Happened to Baby Jane?     1962.0       7.845150
# 209                           King Kong     1933.0       7.794161
# 23469                           Get Out     2017.0       7.787589
# 10519                 Shaun of the Dead     2004.0       7.784206
# 5239                           Predator     1987.0       7.779883
# 14268              Let the Right One In     2008.0       7.758624
# 2523           Night of the Living Dead     1968.0       7.735137

# %% [markdown]
# Les resultats sont pertinents, j'exporte quelque données pour crée un streamlit

# %%
import pickle

with open('data_reco.pkl', 'wb') as f:
    pickle.dump({
        'cast_final_Q92': cast_final_Q92,
        'genre_cols': genre_cols,
        'genre_matrice': genre_matrice,
        'cast_matrice': cast_matrice,
        'tags_matrice': tags_matrice,
    }, f)

# %% [markdown]
# A suivre:
#
# - mode "surprends-moi" par genre (tirage aléatoire pondéré au lieu du top n)
# - filtre par plage d'années
# - filtre par acteur
